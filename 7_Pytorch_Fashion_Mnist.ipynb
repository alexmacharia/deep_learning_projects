# %% [markdown]
# <a href="https://colab.research.google.com/github/alexmacharia/deep_learning_projects/blob/main/7_Pytorch_Fashion_Mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import PIL

import torchvision
import torchvision.transforms as transforms

import torch.optim as optim
import torch.nn as nn

print("GPU available: {}".format(torch.cuda.is_available()))
device = 'cuda'
# Out:
# GPU available: False

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5, ), (0.5, ))])

# %%
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                             download=True, transform=transform)

testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                            download=True, transform=transform)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:02<00:00, 11880697.19it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 200910.92it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:01<00:00, 3695705.34it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 11503610.54it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress',
           'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot')

# %%
print(trainset.data.shape)
print(testset.data.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
num_of_images = 50

for index in range(1, num_of_images + 1):
  plt.subplot(5, 10, index)
  plt.axis('off')
  plt.imshow(trainset.data[index], cmap='gray_r')

# %%
import numpy as np

def imshow(img):
  img = img / 2 + 0.5
  npimg = img.numpy()
  plt.imshow(np.transpose(npimg, (1,2,0)))
  plt.show()

dataiter = iter(trainloader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))

print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fcc8a7e1d80>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#     Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7fcc8a7e1d80>self._shutdown_workers()
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1479, in __del__
#         self._shutdown_workers()if w.is_alive():
#
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1462, in _shutdown_workers
#         assert self._parent_pid == os.getpid(), 'can only test a child process'if w.is_alive():
#
# AssertionError  File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# : AssertionErrorcan only test a child process:
# can only test a child process
# T-shirt/top Trouser T-shirt/top  Coat Sandal   Bag   Bag Trouser

# %%
import torch.nn.functional as F

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.conv1 = nn.Conv2d(1, 32, 3)
    self.conv2 = nn.Conv2d(32, 64, 3)
    self.pool = nn.MaxPool2d(2, 2)
    self.fc1 = nn.Linear(64 * 12 * 12, 128)
    self.fc2 = nn.Linear(128, 10)

  def forward(self, x):
    x = F.relu(self.conv1(x))
    x = self.pool(F.relu(self.conv2(x)))
    x = x.view(-1, 64 * 12 * 12)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
epochs = 15

epoch_log = []
loss_log = []
acc_log = []

for epoch in range(epochs):
  print(f'Starting Epoch: {epoch+1}...')

  running_loss = 0.0

  for i, data in enumerate(trainloader, 0):
    inputs, labels = data

    inputs = inputs.to(device)
    labels = labels.to(device)

    optimizer.zero_grad()

    outputs = net(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item()
    if i % 100 == 99:
      correct = 0
      total = 0

      with torch.no_grad():
        for data in testloader:
          images, labels = data
          images = images.to(device)
          labels = labels.to(device)

          outputs = net(images)

          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total
        epoch_num = epoch + 1
        actual_loss = running_loss / 50
        print(f'Epoch: {epoch_num}, Mini=Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
        running_loss = 0.0

  epoch_log.append(epoch_num)
  loss_log.append(actual_loss)
  acc_log.append(accuracy)

print('Finished Training')
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini=Batches Completed: 100, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 200, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 300, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 400, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 500, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 600, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 800, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 900, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 1000, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 1100, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 1200, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 1300, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 1400, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 1500, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 1600, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 1700, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 1, Mini=Batches Completed: 1800, Loss: 4.608, Test Accuracy = 5.420%
# Starting Epoch: 2...
# Epoch: 2, Mini=Batches Completed: 100, Loss: 4.613, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 200, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 300, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 400, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 500, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 600, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 700, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 800, Loss: 4.603, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 900, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 1000, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 1100, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 1200, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 1300, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 1400, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 1500, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 1600, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 1700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 2, Mini=Batches Completed: 1800, Loss: 4.608, Test Accuracy = 5.420%
# Starting Epoch: 3...
# Epoch: 3, Mini=Batches Completed: 100, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 200, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 300, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 400, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 500, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 600, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 800, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 900, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 1000, Loss: 4.602, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 1100, Loss: 4.603, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 1200, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 1300, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 1400, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 1500, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 1600, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 1700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 3, Mini=Batches Completed: 1800, Loss: 4.609, Test Accuracy = 5.420%
# Starting Epoch: 4...
# Epoch: 4, Mini=Batches Completed: 100, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 200, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 300, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 400, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 500, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 600, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 700, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 800, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 900, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 1000, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 1100, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 1200, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 1300, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 1400, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 1500, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 1600, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 1700, Loss: 4.613, Test Accuracy = 5.420%
# Epoch: 4, Mini=Batches Completed: 1800, Loss: 4.605, Test Accuracy = 5.420%
# Starting Epoch: 5...
# Epoch: 5, Mini=Batches Completed: 100, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 200, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 300, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 400, Loss: 4.602, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 500, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 600, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 700, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 800, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 900, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 1000, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 1100, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 1200, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 1300, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 1400, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 1500, Loss: 4.603, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 1600, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 1700, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 5, Mini=Batches Completed: 1800, Loss: 4.609, Test Accuracy = 5.420%
# Starting Epoch: 6...
# Epoch: 6, Mini=Batches Completed: 100, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 200, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 300, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 400, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 500, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 600, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 800, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 900, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 1000, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 1100, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 1200, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 1300, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 1400, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 1500, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 1600, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 1700, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 6, Mini=Batches Completed: 1800, Loss: 4.612, Test Accuracy = 5.420%
# Starting Epoch: 7...
# Epoch: 7, Mini=Batches Completed: 100, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 200, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 300, Loss: 4.614, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 400, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 500, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 600, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 800, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 900, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 1000, Loss: 4.602, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 1100, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 1200, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 1300, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 1400, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 1500, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 1600, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 1700, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 7, Mini=Batches Completed: 1800, Loss: 4.607, Test Accuracy = 5.420%
# Starting Epoch: 8...
# Epoch: 8, Mini=Batches Completed: 100, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 200, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 300, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 400, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 500, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 600, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 700, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 800, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 900, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 1000, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 1100, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 1200, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 1300, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 1400, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 1500, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 1600, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 1700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 8, Mini=Batches Completed: 1800, Loss: 4.611, Test Accuracy = 5.420%
# Starting Epoch: 9...
# Epoch: 9, Mini=Batches Completed: 100, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 200, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 300, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 400, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 500, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 600, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 800, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 900, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 1000, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 1100, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 1200, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 1300, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 1400, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 1500, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 1600, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 1700, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 9, Mini=Batches Completed: 1800, Loss: 4.609, Test Accuracy = 5.420%
# Starting Epoch: 10...
# Epoch: 10, Mini=Batches Completed: 100, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 200, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 300, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 400, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 500, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 600, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 700, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 800, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 900, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 1000, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 1100, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 1200, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 1300, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 1400, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 1500, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 1600, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 1700, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 10, Mini=Batches Completed: 1800, Loss: 4.608, Test Accuracy = 5.420%
# Starting Epoch: 11...
# Epoch: 11, Mini=Batches Completed: 100, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 200, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 300, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 400, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 500, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 600, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 700, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 800, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 900, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 1000, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 1100, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 1200, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 1300, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 1400, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 1500, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 1600, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 1700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 11, Mini=Batches Completed: 1800, Loss: 4.602, Test Accuracy = 5.420%
# Starting Epoch: 12...
# Epoch: 12, Mini=Batches Completed: 100, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 200, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 300, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 400, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 500, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 600, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 800, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 900, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 1000, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 1100, Loss: 4.604, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 1200, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 1300, Loss: 4.613, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 1400, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 1500, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 1600, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 1700, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 12, Mini=Batches Completed: 1800, Loss: 4.608, Test Accuracy = 5.420%
# Starting Epoch: 13...
# Epoch: 13, Mini=Batches Completed: 100, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 200, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 300, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 400, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 500, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 600, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 700, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 800, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 900, Loss: 4.603, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 1000, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 1100, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 1200, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 1300, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 1400, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 1500, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 1600, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 1700, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 13, Mini=Batches Completed: 1800, Loss: 4.606, Test Accuracy = 5.420%
# Starting Epoch: 14...
# Epoch: 14, Mini=Batches Completed: 100, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 200, Loss: 4.606, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 300, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 400, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 500, Loss: 4.612, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 600, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 700, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 800, Loss: 4.603, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 900, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 1000, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 1100, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 1200, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 1300, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 1400, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 1500, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 1600, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 1700, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 14, Mini=Batches Completed: 1800, Loss: 4.608, Test Accuracy = 5.420%
# Starting Epoch: 15...
# Epoch: 15, Mini=Batches Completed: 100, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 200, Loss: 4.613, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 300, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 400, Loss: 4.611, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 500, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 600, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 700, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 800, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 900, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 1000, Loss: 4.609, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 1100, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 1200, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 1300, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 1400, Loss: 4.610, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 1500, Loss: 4.607, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 1600, Loss: 4.608, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 1700, Loss: 4.605, Test Accuracy = 5.420%
# Epoch: 15, Mini=Batches Completed: 1800, Loss: 4.609, Test Accuracy = 5.420%

# %%
correct = 0
total = 0

with torch.no_grad():
  for data in testloader:
    images, labels = data

    images = images.to(device)
    labels = labels.to(device)
    outputs = net(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')

# %%
fig, ax1 = plt.subplots()

plt.title('Accuracy & Loss vs Epoch Mini-Batches')
plt.xticks(rotation=45)

ax2 = ax1.twinx()

ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, acc_log, 'b-')


ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()

# %%
PATH = './fashion_mnist_cnn_net.pth'
torch.save(net.state_dict(), PATH)

# %%
data_aug_transform = transforms.Compose([
    transforms.RandomAffine(degrees=10, translate=(0.05,0.05), shear=5),
    transforms.ColorJitter(hue=.05, saturation=.05),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.Grayscale(num_output_channels=1)
])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fcdd7d6aa280> in <cell line: 1>()
#       3     transforms.ColorJitter(hue=.05, saturation=.05),
#       4     transforms.RandomHorizontalFlip(),
# ----> 5     transforms.RandomRotation(15, resample=PIL.Image.BILINEAR),
#       6     transforms.Grayscale(num_output_channels=1)
#       7 ])
#
# TypeError: RandomRotation.__init__() got an unexpected keyword argument 'resample'

# %%
def shaowAugmentations(image, augmentations=6):
  fig = plt.figure()
  for i in range(augmentations):
    a = fig.add_subplot(1, augmentations, i+1)
    img = data_aug_transform(image)
    imshow(img, cmap='gray_r')
    plt.axis('off')

# %%
image = trainset.data[0].numpy()

img_pil = PIL.Image.fromarray(Image)

showAugmentations(img_pil, 8)
