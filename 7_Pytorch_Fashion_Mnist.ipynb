# %% [markdown]
# <a href="https://colab.research.google.com/github/alexmacharia/deep_learning_projects/blob/main/7_Pytorch_Fashion_Mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import PIL

import torchvision
import torchvision.transforms as transforms

import torch.optim as optim
import torch.nn as nn

print("GPU available: {}".format(torch.cuda.is_available()))
device = 'cuda'
# Out:
# GPU available: True

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5, ), (0.5, ))])

# %%
trainset = torchvision.datasets.FashionMNIST(root='./data', train=True,
                                             download=True, transform=transform)

testset = torchvision.datasets.FashionMNIST(root='./data', train=False,
                                            download=True, transform=transform)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:01<00:00, 15731260.45it/s]
# Extracting ./data/FashionMNIST/raw/train-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 265332.55it/s]
# Extracting ./data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 5062087.40it/s]
# Extracting ./data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to ./data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 17874401.48it/s]
# Extracting ./data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/FashionMNIST/raw

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)

classes = ('T-shirt/top', 'Trouser', 'Pullover', 'Dress',
           'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot')

# %%
print(trainset.data.shape)
print(testset.data.shape)
# Out:
# torch.Size([60000, 28, 28])
# torch.Size([10000, 28, 28])

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
num_of_images = 50

for index in range(1, num_of_images + 1):
  plt.subplot(5, 10, index)
  plt.axis('off')
  plt.imshow(trainset.data[index], cmap='gray_r')

# %%
import numpy as np

def imshow(img):
  img = img / 2 + 0.5
  npimg = img.numpy()
  plt.imshow(np.transpose(npimg, (1,2,0)))
  plt.show()

dataiter = iter(trainloader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))

print(' '.join('%5s' % classes[labels[j]] for j in range(8)))
# Out:
#   Bag   Bag Dress Pullover Trouser Sneaker   Bag T-shirt/top

# %%
import torch.nn.functional as F

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.conv1 = nn.Conv2d(1, 32, 3)
    self.conv2 = nn.Conv2d(32, 64, 3)
    self.pool = nn.MaxPool2d(2, 2)
    self.fc1 = nn.Linear(64 * 12 * 12, 128)
    self.fc2 = nn.Linear(128, 10)

  def forward(self, x):
    x = F.relu(self.conv1(x))
    x = self.pool(F.relu(self.conv2(x)))
    x = x.view(-1, 64 * 12 * 12)
    x = F.relu(self.fc1(x))
    x = self.fc2(x)
    return x

net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
epochs = 15

epoch_log = []
loss_log = []
acc_log = []

for epoch in range(epochs):
  print(f'Starting Epoch: {epoch+1}...')

  running_loss = 0.0

  for i, data in enumerate(trainloader, 0):
    inputs, labels = data

    inputs = inputs.to(device)
    labels = labels.to(device)

    optimizer.zero_grad()

    outputs = net(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item()
    if i % 100 == 99:
      correct = 0
      total = 0

      with torch.no_grad():
        for data in testloader:
          images, labels = data
          images = images.to(device)
          labels = labels.to(device)

          outputs = net(images)

          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()

        accuracy = 100 * correct / total
        epoch_num = epoch + 1
        actual_loss = running_loss / 50
        print(f'Epoch: {epoch_num}, Mini=Batches Completed: {(i+1)}, Loss: {actual_loss:.3f}, Test Accuracy = {accuracy:.3f}%')
        running_loss = 0.0

  epoch_log.append(epoch_num)
  loss_log.append(actual_loss)
  acc_log.append(accuracy)

print('Finished Training')
# Out:
# Starting Epoch: 1...
# Epoch: 1, Mini=Batches Completed: 100, Loss: 4.020, Test Accuracy = 62.540%
# Epoch: 1, Mini=Batches Completed: 200, Loss: 1.847, Test Accuracy = 71.990%
# Epoch: 1, Mini=Batches Completed: 300, Loss: 1.484, Test Accuracy = 69.630%
# Epoch: 1, Mini=Batches Completed: 400, Loss: 1.304, Test Accuracy = 76.580%
# Epoch: 1, Mini=Batches Completed: 500, Loss: 1.319, Test Accuracy = 75.730%
# Epoch: 1, Mini=Batches Completed: 600, Loss: 1.178, Test Accuracy = 77.790%
# Epoch: 1, Mini=Batches Completed: 700, Loss: 1.181, Test Accuracy = 78.300%
# Epoch: 1, Mini=Batches Completed: 800, Loss: 1.116, Test Accuracy = 77.890%
# Epoch: 1, Mini=Batches Completed: 900, Loss: 1.067, Test Accuracy = 76.580%
# Epoch: 1, Mini=Batches Completed: 1000, Loss: 1.092, Test Accuracy = 80.280%
# Epoch: 1, Mini=Batches Completed: 1100, Loss: 1.055, Test Accuracy = 76.290%
# Epoch: 1, Mini=Batches Completed: 1200, Loss: 1.064, Test Accuracy = 80.460%
# Epoch: 1, Mini=Batches Completed: 1300, Loss: 0.996, Test Accuracy = 80.720%
# Epoch: 1, Mini=Batches Completed: 1400, Loss: 0.918, Test Accuracy = 81.090%
# Epoch: 1, Mini=Batches Completed: 1500, Loss: 0.925, Test Accuracy = 80.850%
# Epoch: 1, Mini=Batches Completed: 1600, Loss: 0.930, Test Accuracy = 83.010%
# Epoch: 1, Mini=Batches Completed: 1700, Loss: 0.980, Test Accuracy = 82.230%
# Epoch: 1, Mini=Batches Completed: 1800, Loss: 0.923, Test Accuracy = 82.980%
# Starting Epoch: 2...
# Epoch: 2, Mini=Batches Completed: 100, Loss: 0.898, Test Accuracy = 83.810%
# Epoch: 2, Mini=Batches Completed: 200, Loss: 0.872, Test Accuracy = 82.120%
# Epoch: 2, Mini=Batches Completed: 300, Loss: 0.893, Test Accuracy = 83.650%
# Epoch: 2, Mini=Batches Completed: 400, Loss: 0.872, Test Accuracy = 84.260%
# Epoch: 2, Mini=Batches Completed: 500, Loss: 0.861, Test Accuracy = 83.890%
# Epoch: 2, Mini=Batches Completed: 600, Loss: 0.863, Test Accuracy = 82.630%
# Epoch: 2, Mini=Batches Completed: 700, Loss: 0.836, Test Accuracy = 84.210%
# Epoch: 2, Mini=Batches Completed: 800, Loss: 0.802, Test Accuracy = 84.700%
# Epoch: 2, Mini=Batches Completed: 900, Loss: 0.830, Test Accuracy = 84.060%
# Epoch: 2, Mini=Batches Completed: 1000, Loss: 0.787, Test Accuracy = 83.850%
# Epoch: 2, Mini=Batches Completed: 1100, Loss: 0.844, Test Accuracy = 85.320%
# Epoch: 2, Mini=Batches Completed: 1200, Loss: 0.751, Test Accuracy = 85.050%
# Epoch: 2, Mini=Batches Completed: 1300, Loss: 0.827, Test Accuracy = 85.320%
# Epoch: 2, Mini=Batches Completed: 1400, Loss: 0.774, Test Accuracy = 84.050%
# Epoch: 2, Mini=Batches Completed: 1500, Loss: 0.774, Test Accuracy = 84.730%
# Epoch: 2, Mini=Batches Completed: 1600, Loss: 0.803, Test Accuracy = 85.530%
# Epoch: 2, Mini=Batches Completed: 1700, Loss: 0.739, Test Accuracy = 83.980%
# Epoch: 2, Mini=Batches Completed: 1800, Loss: 0.783, Test Accuracy = 84.020%
# Starting Epoch: 3...
# Epoch: 3, Mini=Batches Completed: 100, Loss: 0.805, Test Accuracy = 86.190%
# Epoch: 3, Mini=Batches Completed: 200, Loss: 0.718, Test Accuracy = 85.030%
# Epoch: 3, Mini=Batches Completed: 300, Loss: 0.742, Test Accuracy = 83.850%
# Epoch: 3, Mini=Batches Completed: 400, Loss: 0.691, Test Accuracy = 86.320%
# Epoch: 3, Mini=Batches Completed: 500, Loss: 0.715, Test Accuracy = 86.590%
# Epoch: 3, Mini=Batches Completed: 600, Loss: 0.682, Test Accuracy = 86.270%
# Epoch: 3, Mini=Batches Completed: 700, Loss: 0.709, Test Accuracy = 85.680%
# Epoch: 3, Mini=Batches Completed: 800, Loss: 0.732, Test Accuracy = 85.190%
# Epoch: 3, Mini=Batches Completed: 900, Loss: 0.686, Test Accuracy = 86.400%
# Epoch: 3, Mini=Batches Completed: 1000, Loss: 0.686, Test Accuracy = 86.200%
# Epoch: 3, Mini=Batches Completed: 1100, Loss: 0.746, Test Accuracy = 86.500%
# Epoch: 3, Mini=Batches Completed: 1200, Loss: 0.690, Test Accuracy = 87.180%
# Epoch: 3, Mini=Batches Completed: 1300, Loss: 0.681, Test Accuracy = 85.370%
# Epoch: 3, Mini=Batches Completed: 1400, Loss: 0.715, Test Accuracy = 86.830%
# Epoch: 3, Mini=Batches Completed: 1500, Loss: 0.685, Test Accuracy = 86.300%
# Epoch: 3, Mini=Batches Completed: 1600, Loss: 0.710, Test Accuracy = 87.160%
# Epoch: 3, Mini=Batches Completed: 1700, Loss: 0.686, Test Accuracy = 87.280%
# Epoch: 3, Mini=Batches Completed: 1800, Loss: 0.712, Test Accuracy = 86.630%
# Starting Epoch: 4...
# Epoch: 4, Mini=Batches Completed: 100, Loss: 0.637, Test Accuracy = 87.370%
# Epoch: 4, Mini=Batches Completed: 200, Loss: 0.695, Test Accuracy = 87.260%
# Epoch: 4, Mini=Batches Completed: 300, Loss: 0.626, Test Accuracy = 87.740%
# Epoch: 4, Mini=Batches Completed: 400, Loss: 0.633, Test Accuracy = 87.020%
# Epoch: 4, Mini=Batches Completed: 500, Loss: 0.671, Test Accuracy = 87.370%
# Epoch: 4, Mini=Batches Completed: 600, Loss: 0.650, Test Accuracy = 87.800%
# Epoch: 4, Mini=Batches Completed: 700, Loss: 0.582, Test Accuracy = 87.690%
# Epoch: 4, Mini=Batches Completed: 800, Loss: 0.700, Test Accuracy = 87.950%
# Epoch: 4, Mini=Batches Completed: 900, Loss: 0.654, Test Accuracy = 87.700%
# Epoch: 4, Mini=Batches Completed: 1000, Loss: 0.580, Test Accuracy = 87.710%
# Epoch: 4, Mini=Batches Completed: 1100, Loss: 0.638, Test Accuracy = 88.070%
# Epoch: 4, Mini=Batches Completed: 1200, Loss: 0.641, Test Accuracy = 87.390%
# Epoch: 4, Mini=Batches Completed: 1300, Loss: 0.608, Test Accuracy = 87.210%
# Epoch: 4, Mini=Batches Completed: 1400, Loss: 0.663, Test Accuracy = 87.900%
# Epoch: 4, Mini=Batches Completed: 1500, Loss: 0.640, Test Accuracy = 88.020%
# Epoch: 4, Mini=Batches Completed: 1600, Loss: 0.633, Test Accuracy = 87.590%
# Epoch: 4, Mini=Batches Completed: 1700, Loss: 0.619, Test Accuracy = 87.530%
# Epoch: 4, Mini=Batches Completed: 1800, Loss: 0.647, Test Accuracy = 88.290%
# Starting Epoch: 5...
# Epoch: 5, Mini=Batches Completed: 100, Loss: 0.606, Test Accuracy = 87.590%
# Epoch: 5, Mini=Batches Completed: 200, Loss: 0.609, Test Accuracy = 87.460%
# Epoch: 5, Mini=Batches Completed: 300, Loss: 0.599, Test Accuracy = 87.320%
# Epoch: 5, Mini=Batches Completed: 400, Loss: 0.571, Test Accuracy = 88.180%
# Epoch: 5, Mini=Batches Completed: 500, Loss: 0.578, Test Accuracy = 88.030%
# Epoch: 5, Mini=Batches Completed: 600, Loss: 0.617, Test Accuracy = 87.360%
# Epoch: 5, Mini=Batches Completed: 700, Loss: 0.592, Test Accuracy = 88.280%
# Epoch: 5, Mini=Batches Completed: 800, Loss: 0.582, Test Accuracy = 88.310%
# Epoch: 5, Mini=Batches Completed: 900, Loss: 0.564, Test Accuracy = 88.140%
# Epoch: 5, Mini=Batches Completed: 1000, Loss: 0.550, Test Accuracy = 87.860%
# Epoch: 5, Mini=Batches Completed: 1100, Loss: 0.616, Test Accuracy = 88.510%
# Epoch: 5, Mini=Batches Completed: 1200, Loss: 0.608, Test Accuracy = 88.710%
# Epoch: 5, Mini=Batches Completed: 1300, Loss: 0.540, Test Accuracy = 88.230%
# Epoch: 5, Mini=Batches Completed: 1400, Loss: 0.571, Test Accuracy = 88.470%
# Epoch: 5, Mini=Batches Completed: 1500, Loss: 0.589, Test Accuracy = 88.660%
# Epoch: 5, Mini=Batches Completed: 1600, Loss: 0.568, Test Accuracy = 88.110%
# Epoch: 5, Mini=Batches Completed: 1700, Loss: 0.621, Test Accuracy = 88.920%
# Epoch: 5, Mini=Batches Completed: 1800, Loss: 0.550, Test Accuracy = 89.050%
# Starting Epoch: 6...
# Epoch: 6, Mini=Batches Completed: 100, Loss: 0.556, Test Accuracy = 88.720%
# Epoch: 6, Mini=Batches Completed: 200, Loss: 0.551, Test Accuracy = 87.570%
# Epoch: 6, Mini=Batches Completed: 300, Loss: 0.587, Test Accuracy = 88.910%
# Epoch: 6, Mini=Batches Completed: 400, Loss: 0.551, Test Accuracy = 89.180%
# Epoch: 6, Mini=Batches Completed: 500, Loss: 0.549, Test Accuracy = 88.620%
# Epoch: 6, Mini=Batches Completed: 600, Loss: 0.532, Test Accuracy = 89.080%
# Epoch: 6, Mini=Batches Completed: 700, Loss: 0.518, Test Accuracy = 89.090%
# Epoch: 6, Mini=Batches Completed: 800, Loss: 0.538, Test Accuracy = 88.710%
# Epoch: 6, Mini=Batches Completed: 900, Loss: 0.537, Test Accuracy = 89.010%
# Epoch: 6, Mini=Batches Completed: 1000, Loss: 0.591, Test Accuracy = 88.810%
# Epoch: 6, Mini=Batches Completed: 1100, Loss: 0.520, Test Accuracy = 89.370%
# Epoch: 6, Mini=Batches Completed: 1200, Loss: 0.516, Test Accuracy = 88.140%
# Epoch: 6, Mini=Batches Completed: 1300, Loss: 0.543, Test Accuracy = 89.380%
# Epoch: 6, Mini=Batches Completed: 1400, Loss: 0.553, Test Accuracy = 89.460%
# Epoch: 6, Mini=Batches Completed: 1500, Loss: 0.491, Test Accuracy = 89.040%
# Epoch: 6, Mini=Batches Completed: 1600, Loss: 0.520, Test Accuracy = 88.690%
# Epoch: 6, Mini=Batches Completed: 1700, Loss: 0.568, Test Accuracy = 88.410%
# Epoch: 6, Mini=Batches Completed: 1800, Loss: 0.537, Test Accuracy = 89.100%
# Starting Epoch: 7...
# Epoch: 7, Mini=Batches Completed: 100, Loss: 0.542, Test Accuracy = 88.540%
# Epoch: 7, Mini=Batches Completed: 200, Loss: 0.519, Test Accuracy = 89.080%
# Epoch: 7, Mini=Batches Completed: 300, Loss: 0.542, Test Accuracy = 89.620%
# Epoch: 7, Mini=Batches Completed: 400, Loss: 0.489, Test Accuracy = 89.920%
# Epoch: 7, Mini=Batches Completed: 500, Loss: 0.545, Test Accuracy = 89.070%
# Epoch: 7, Mini=Batches Completed: 600, Loss: 0.480, Test Accuracy = 89.530%
# Epoch: 7, Mini=Batches Completed: 700, Loss: 0.507, Test Accuracy = 89.080%
# Epoch: 7, Mini=Batches Completed: 800, Loss: 0.488, Test Accuracy = 89.660%
# Epoch: 7, Mini=Batches Completed: 900, Loss: 0.512, Test Accuracy = 88.790%
# Epoch: 7, Mini=Batches Completed: 1000, Loss: 0.506, Test Accuracy = 89.490%
# Epoch: 7, Mini=Batches Completed: 1100, Loss: 0.512, Test Accuracy = 89.100%
# Epoch: 7, Mini=Batches Completed: 1200, Loss: 0.477, Test Accuracy = 89.560%
# Epoch: 7, Mini=Batches Completed: 1300, Loss: 0.514, Test Accuracy = 89.630%
# Epoch: 7, Mini=Batches Completed: 1400, Loss: 0.517, Test Accuracy = 89.480%
# Epoch: 7, Mini=Batches Completed: 1500, Loss: 0.493, Test Accuracy = 89.700%
# Epoch: 7, Mini=Batches Completed: 1600, Loss: 0.520, Test Accuracy = 90.070%
# Epoch: 7, Mini=Batches Completed: 1700, Loss: 0.495, Test Accuracy = 90.010%
# Epoch: 7, Mini=Batches Completed: 1800, Loss: 0.480, Test Accuracy = 89.990%
# Starting Epoch: 8...
# Epoch: 8, Mini=Batches Completed: 100, Loss: 0.473, Test Accuracy = 89.790%
# Epoch: 8, Mini=Batches Completed: 200, Loss: 0.474, Test Accuracy = 89.600%
# Epoch: 8, Mini=Batches Completed: 300, Loss: 0.490, Test Accuracy = 89.740%
# Epoch: 8, Mini=Batches Completed: 400, Loss: 0.472, Test Accuracy = 90.120%
# Epoch: 8, Mini=Batches Completed: 500, Loss: 0.430, Test Accuracy = 89.770%
# Epoch: 8, Mini=Batches Completed: 600, Loss: 0.512, Test Accuracy = 90.100%
# Epoch: 8, Mini=Batches Completed: 700, Loss: 0.442, Test Accuracy = 89.230%
# Epoch: 8, Mini=Batches Completed: 800, Loss: 0.473, Test Accuracy = 89.210%
# Epoch: 8, Mini=Batches Completed: 900, Loss: 0.469, Test Accuracy = 89.650%
# Epoch: 8, Mini=Batches Completed: 1000, Loss: 0.482, Test Accuracy = 90.260%
# Epoch: 8, Mini=Batches Completed: 1100, Loss: 0.453, Test Accuracy = 90.040%
# Epoch: 8, Mini=Batches Completed: 1200, Loss: 0.456, Test Accuracy = 89.640%
# Epoch: 8, Mini=Batches Completed: 1300, Loss: 0.477, Test Accuracy = 90.220%
# Epoch: 8, Mini=Batches Completed: 1400, Loss: 0.469, Test Accuracy = 89.870%
# Epoch: 8, Mini=Batches Completed: 1500, Loss: 0.496, Test Accuracy = 90.020%
# Epoch: 8, Mini=Batches Completed: 1600, Loss: 0.507, Test Accuracy = 90.440%
# Epoch: 8, Mini=Batches Completed: 1700, Loss: 0.462, Test Accuracy = 89.750%
# Epoch: 8, Mini=Batches Completed: 1800, Loss: 0.484, Test Accuracy = 90.220%
# Starting Epoch: 9...
# Epoch: 9, Mini=Batches Completed: 100, Loss: 0.451, Test Accuracy = 90.130%
# Epoch: 9, Mini=Batches Completed: 200, Loss: 0.465, Test Accuracy = 89.990%
# Epoch: 9, Mini=Batches Completed: 300, Loss: 0.460, Test Accuracy = 90.220%
# Epoch: 9, Mini=Batches Completed: 400, Loss: 0.448, Test Accuracy = 89.720%
# Epoch: 9, Mini=Batches Completed: 500, Loss: 0.420, Test Accuracy = 90.230%
# Epoch: 9, Mini=Batches Completed: 600, Loss: 0.441, Test Accuracy = 90.130%
# Epoch: 9, Mini=Batches Completed: 700, Loss: 0.468, Test Accuracy = 89.750%
# Epoch: 9, Mini=Batches Completed: 800, Loss: 0.496, Test Accuracy = 90.300%
# Epoch: 9, Mini=Batches Completed: 900, Loss: 0.419, Test Accuracy = 89.830%
# Epoch: 9, Mini=Batches Completed: 1000, Loss: 0.419, Test Accuracy = 89.510%
# Epoch: 9, Mini=Batches Completed: 1100, Loss: 0.457, Test Accuracy = 89.580%
# Epoch: 9, Mini=Batches Completed: 1200, Loss: 0.454, Test Accuracy = 89.300%
# Epoch: 9, Mini=Batches Completed: 1300, Loss: 0.461, Test Accuracy = 90.430%
# Epoch: 9, Mini=Batches Completed: 1400, Loss: 0.432, Test Accuracy = 90.250%
# Epoch: 9, Mini=Batches Completed: 1500, Loss: 0.422, Test Accuracy = 90.470%
# Epoch: 9, Mini=Batches Completed: 1600, Loss: 0.405, Test Accuracy = 90.240%
# Epoch: 9, Mini=Batches Completed: 1700, Loss: 0.422, Test Accuracy = 90.320%
# Epoch: 9, Mini=Batches Completed: 1800, Loss: 0.444, Test Accuracy = 90.560%
# Starting Epoch: 10...
# Epoch: 10, Mini=Batches Completed: 100, Loss: 0.418, Test Accuracy = 90.000%
# Epoch: 10, Mini=Batches Completed: 200, Loss: 0.417, Test Accuracy = 89.820%
# Epoch: 10, Mini=Batches Completed: 300, Loss: 0.436, Test Accuracy = 90.900%
# Epoch: 10, Mini=Batches Completed: 400, Loss: 0.413, Test Accuracy = 90.120%
# Epoch: 10, Mini=Batches Completed: 500, Loss: 0.434, Test Accuracy = 90.740%
# Epoch: 10, Mini=Batches Completed: 600, Loss: 0.398, Test Accuracy = 90.200%
# Epoch: 10, Mini=Batches Completed: 700, Loss: 0.445, Test Accuracy = 90.300%
# Epoch: 10, Mini=Batches Completed: 800, Loss: 0.433, Test Accuracy = 90.440%
# Epoch: 10, Mini=Batches Completed: 900, Loss: 0.431, Test Accuracy = 90.580%
# Epoch: 10, Mini=Batches Completed: 1000, Loss: 0.400, Test Accuracy = 90.430%
# Epoch: 10, Mini=Batches Completed: 1100, Loss: 0.435, Test Accuracy = 90.380%
# Epoch: 10, Mini=Batches Completed: 1200, Loss: 0.440, Test Accuracy = 90.840%
# Epoch: 10, Mini=Batches Completed: 1300, Loss: 0.378, Test Accuracy = 90.320%
# Epoch: 10, Mini=Batches Completed: 1400, Loss: 0.407, Test Accuracy = 90.580%
# Epoch: 10, Mini=Batches Completed: 1500, Loss: 0.368, Test Accuracy = 90.950%
# Epoch: 10, Mini=Batches Completed: 1600, Loss: 0.415, Test Accuracy = 90.810%
# Epoch: 10, Mini=Batches Completed: 1700, Loss: 0.395, Test Accuracy = 91.260%
# Epoch: 10, Mini=Batches Completed: 1800, Loss: 0.406, Test Accuracy = 90.660%
# Starting Epoch: 11...
# Epoch: 11, Mini=Batches Completed: 100, Loss: 0.378, Test Accuracy = 90.690%
# Epoch: 11, Mini=Batches Completed: 200, Loss: 0.395, Test Accuracy = 90.800%
# Epoch: 11, Mini=Batches Completed: 300, Loss: 0.373, Test Accuracy = 90.850%
# Epoch: 11, Mini=Batches Completed: 400, Loss: 0.361, Test Accuracy = 90.640%
# Epoch: 11, Mini=Batches Completed: 500, Loss: 0.398, Test Accuracy = 90.430%
# Epoch: 11, Mini=Batches Completed: 600, Loss: 0.399, Test Accuracy = 90.940%
# Epoch: 11, Mini=Batches Completed: 700, Loss: 0.406, Test Accuracy = 90.590%
# Epoch: 11, Mini=Batches Completed: 800, Loss: 0.408, Test Accuracy = 90.700%
# Epoch: 11, Mini=Batches Completed: 900, Loss: 0.420, Test Accuracy = 90.880%
# Epoch: 11, Mini=Batches Completed: 1000, Loss: 0.415, Test Accuracy = 90.930%
# Epoch: 11, Mini=Batches Completed: 1100, Loss: 0.415, Test Accuracy = 90.990%
# Epoch: 11, Mini=Batches Completed: 1200, Loss: 0.397, Test Accuracy = 90.880%
# Epoch: 11, Mini=Batches Completed: 1300, Loss: 0.429, Test Accuracy = 90.340%
# Epoch: 11, Mini=Batches Completed: 1400, Loss: 0.368, Test Accuracy = 90.710%
# Epoch: 11, Mini=Batches Completed: 1500, Loss: 0.414, Test Accuracy = 90.310%
# Epoch: 11, Mini=Batches Completed: 1600, Loss: 0.367, Test Accuracy = 89.680%
# Epoch: 11, Mini=Batches Completed: 1700, Loss: 0.399, Test Accuracy = 90.240%
# Epoch: 11, Mini=Batches Completed: 1800, Loss: 0.374, Test Accuracy = 90.930%
# Starting Epoch: 12...
# Epoch: 12, Mini=Batches Completed: 100, Loss: 0.374, Test Accuracy = 90.710%
# Epoch: 12, Mini=Batches Completed: 200, Loss: 0.369, Test Accuracy = 90.420%
# Epoch: 12, Mini=Batches Completed: 300, Loss: 0.368, Test Accuracy = 90.310%
# Epoch: 12, Mini=Batches Completed: 400, Loss: 0.390, Test Accuracy = 90.540%
# Epoch: 12, Mini=Batches Completed: 500, Loss: 0.361, Test Accuracy = 90.750%
# Epoch: 12, Mini=Batches Completed: 600, Loss: 0.390, Test Accuracy = 90.460%
# Epoch: 12, Mini=Batches Completed: 700, Loss: 0.373, Test Accuracy = 90.570%
# Epoch: 12, Mini=Batches Completed: 800, Loss: 0.417, Test Accuracy = 90.210%
# Epoch: 12, Mini=Batches Completed: 900, Loss: 0.331, Test Accuracy = 90.980%
# Epoch: 12, Mini=Batches Completed: 1000, Loss: 0.397, Test Accuracy = 90.930%
# Epoch: 12, Mini=Batches Completed: 1100, Loss: 0.371, Test Accuracy = 91.080%
# Epoch: 12, Mini=Batches Completed: 1200, Loss: 0.363, Test Accuracy = 90.870%
# Epoch: 12, Mini=Batches Completed: 1300, Loss: 0.368, Test Accuracy = 90.690%
# Epoch: 12, Mini=Batches Completed: 1400, Loss: 0.404, Test Accuracy = 90.980%
# Epoch: 12, Mini=Batches Completed: 1500, Loss: 0.388, Test Accuracy = 90.870%
# Epoch: 12, Mini=Batches Completed: 1600, Loss: 0.365, Test Accuracy = 90.750%
# Epoch: 12, Mini=Batches Completed: 1700, Loss: 0.356, Test Accuracy = 90.680%
# Epoch: 12, Mini=Batches Completed: 1800, Loss: 0.429, Test Accuracy = 90.750%
# Starting Epoch: 13...
# Epoch: 13, Mini=Batches Completed: 100, Loss: 0.308, Test Accuracy = 90.930%
# Epoch: 13, Mini=Batches Completed: 200, Loss: 0.321, Test Accuracy = 90.760%
# Epoch: 13, Mini=Batches Completed: 300, Loss: 0.365, Test Accuracy = 90.120%
# Epoch: 13, Mini=Batches Completed: 400, Loss: 0.337, Test Accuracy = 91.090%
# Epoch: 13, Mini=Batches Completed: 500, Loss: 0.366, Test Accuracy = 90.570%
# Epoch: 13, Mini=Batches Completed: 600, Loss: 0.363, Test Accuracy = 91.270%
# Epoch: 13, Mini=Batches Completed: 700, Loss: 0.320, Test Accuracy = 90.860%
# Epoch: 13, Mini=Batches Completed: 800, Loss: 0.359, Test Accuracy = 91.220%
# Epoch: 13, Mini=Batches Completed: 900, Loss: 0.357, Test Accuracy = 90.960%
# Epoch: 13, Mini=Batches Completed: 1000, Loss: 0.339, Test Accuracy = 91.190%
# Epoch: 13, Mini=Batches Completed: 1100, Loss: 0.369, Test Accuracy = 91.350%
# Epoch: 13, Mini=Batches Completed: 1200, Loss: 0.386, Test Accuracy = 90.180%
# Epoch: 13, Mini=Batches Completed: 1300, Loss: 0.349, Test Accuracy = 91.210%
# Epoch: 13, Mini=Batches Completed: 1400, Loss: 0.365, Test Accuracy = 91.150%
# Epoch: 13, Mini=Batches Completed: 1500, Loss: 0.328, Test Accuracy = 91.100%
# Epoch: 13, Mini=Batches Completed: 1600, Loss: 0.331, Test Accuracy = 90.890%
# Epoch: 13, Mini=Batches Completed: 1700, Loss: 0.387, Test Accuracy = 90.840%
# Epoch: 13, Mini=Batches Completed: 1800, Loss: 0.352, Test Accuracy = 89.150%
# Starting Epoch: 14...
# Epoch: 14, Mini=Batches Completed: 100, Loss: 0.326, Test Accuracy = 91.260%
# Epoch: 14, Mini=Batches Completed: 200, Loss: 0.322, Test Accuracy = 91.340%
# Epoch: 14, Mini=Batches Completed: 300, Loss: 0.348, Test Accuracy = 91.280%
# Epoch: 14, Mini=Batches Completed: 400, Loss: 0.341, Test Accuracy = 91.060%
# Epoch: 14, Mini=Batches Completed: 500, Loss: 0.343, Test Accuracy = 91.010%
# Epoch: 14, Mini=Batches Completed: 600, Loss: 0.350, Test Accuracy = 90.720%
# Epoch: 14, Mini=Batches Completed: 700, Loss: 0.331, Test Accuracy = 91.180%
# Epoch: 14, Mini=Batches Completed: 800, Loss: 0.329, Test Accuracy = 91.070%
# Epoch: 14, Mini=Batches Completed: 900, Loss: 0.330, Test Accuracy = 91.300%
# Epoch: 14, Mini=Batches Completed: 1000, Loss: 0.318, Test Accuracy = 91.300%
# Epoch: 14, Mini=Batches Completed: 1100, Loss: 0.342, Test Accuracy = 90.770%
# Epoch: 14, Mini=Batches Completed: 1200, Loss: 0.314, Test Accuracy = 91.410%
# Epoch: 14, Mini=Batches Completed: 1300, Loss: 0.324, Test Accuracy = 91.020%
# Epoch: 14, Mini=Batches Completed: 1400, Loss: 0.365, Test Accuracy = 91.310%
# Epoch: 14, Mini=Batches Completed: 1500, Loss: 0.313, Test Accuracy = 91.470%
# Epoch: 14, Mini=Batches Completed: 1600, Loss: 0.318, Test Accuracy = 91.480%
# Epoch: 14, Mini=Batches Completed: 1700, Loss: 0.308, Test Accuracy = 90.750%
# Epoch: 14, Mini=Batches Completed: 1800, Loss: 0.360, Test Accuracy = 91.560%
# Starting Epoch: 15...
# Epoch: 15, Mini=Batches Completed: 100, Loss: 0.319, Test Accuracy = 91.130%
# Epoch: 15, Mini=Batches Completed: 200, Loss: 0.282, Test Accuracy = 91.640%
# Epoch: 15, Mini=Batches Completed: 300, Loss: 0.320, Test Accuracy = 91.120%
# Epoch: 15, Mini=Batches Completed: 400, Loss: 0.302, Test Accuracy = 90.890%
# Epoch: 15, Mini=Batches Completed: 500, Loss: 0.307, Test Accuracy = 91.140%
# Epoch: 15, Mini=Batches Completed: 600, Loss: 0.308, Test Accuracy = 91.280%
# Epoch: 15, Mini=Batches Completed: 700, Loss: 0.309, Test Accuracy = 91.150%
# Epoch: 15, Mini=Batches Completed: 800, Loss: 0.318, Test Accuracy = 91.670%
# Epoch: 15, Mini=Batches Completed: 900, Loss: 0.358, Test Accuracy = 91.530%
# Epoch: 15, Mini=Batches Completed: 1000, Loss: 0.310, Test Accuracy = 91.280%
# Epoch: 15, Mini=Batches Completed: 1100, Loss: 0.313, Test Accuracy = 91.600%
# Epoch: 15, Mini=Batches Completed: 1200, Loss: 0.318, Test Accuracy = 91.180%
# Epoch: 15, Mini=Batches Completed: 1300, Loss: 0.342, Test Accuracy = 91.130%
# Epoch: 15, Mini=Batches Completed: 1400, Loss: 0.300, Test Accuracy = 91.120%
# Epoch: 15, Mini=Batches Completed: 1500, Loss: 0.278, Test Accuracy = 91.380%
# Epoch: 15, Mini=Batches Completed: 1600, Loss: 0.327, Test Accuracy = 91.650%
# Epoch: 15, Mini=Batches Completed: 1700, Loss: 0.310, Test Accuracy = 91.370%
# Epoch: 15, Mini=Batches Completed: 1800, Loss: 0.362, Test Accuracy = 91.040%
# Finished Training

# %%
correct = 0
total = 0

with torch.no_grad():
  for data in testloader:
    images, labels = data

    images = images.to(device)
    labels = labels.to(device)
    outputs = net(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Accuracy of the network on the 10000 test images: {accuracy:.4}%')
# Out:
# Accuracy of the network on the 10000 test images: 90.85%

# %%
fig, ax1 = plt.subplots()

plt.title('Accuracy & Loss vs Epoch Mini-Batches')
plt.xticks(rotation=45)

ax2 = ax1.twinx()

ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, acc_log, 'b-')


ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()

# %%
PATH = './fashion_mnist_cnn_net.pth'
torch.save(net.state_dict(), PATH)

# %%
data_aug_transform = transforms.Compose([
    transforms.RandomAffine(degrees=10, translate=(0.05,0.05), shear=5),
    transforms.ColorJitter(hue=.05, saturation=.05),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.Grayscale(num_output_channels=1)
])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-fcdd7d6aa280> in <cell line: 1>()
#       3     transforms.ColorJitter(hue=.05, saturation=.05),
#       4     transforms.RandomHorizontalFlip(),
# ----> 5     transforms.RandomRotation(15, resample=PIL.Image.BILINEAR),
#       6     transforms.Grayscale(num_output_channels=1)
#       7 ])
#
# TypeError: RandomRotation.__init__() got an unexpected keyword argument 'resample'

# %%
def shaowAugmentations(image, augmentations=6):
  fig = plt.figure()
  for i in range(augmentations):
    a = fig.add_subplot(1, augmentations, i+1)
    img = data_aug_transform(image)
    imshow(img, cmap='gray_r')
    plt.axis('off')

# %%
image = trainset.data[0].numpy()

img_pil = PIL.Image.fromarray(Image)

showAugmentations(img_pil, 8)
